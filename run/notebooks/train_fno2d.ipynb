# %% [markdown]
# # Train Model on Brownian Motion PDE

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Necessary Packages

# %%
import torch
import numpy as np
import wandb

from neuralop.models import FNO
from neuralop.losses import LpLoss
from neuralop import Trainer
from matplotlib import pyplot as plt

# %% [markdown]
# ## Dataset

# %%
class BrownianMotionDataset(torch.utils.data.Dataset):
    def __init__(self,
                 N: int,
                 B: int=100, 
                 N_x: int=128,
                 X: tuple[float, float]=(0.0,1.0), 
                 T: float=1.0, 
                 D_range: tuple[float, float]=(1.0, 1.0), 
                 initial_condition: callable=None, 
                 transform: callable=None, 
                 as_prob: bool=False,
                 include_D: bool=False,
                 channels_first: bool=False,
                 seed: int=None, 
                 device: str | torch.device=None):
        """
        Dataset for 1D diffusion (Brownian motion) using closed‐form solution.

        Args:
            N: number of initial conditions (dataset size)
            B: number of time steps per trajectory
            N_x: number of spatial grid points
            X: The spatial domain
            T: total simulation time
            D_range: (min_D, max_D), sampled per sequence
            include_D: whether to include D as part of the input features
            channels_first: Whether to return (B, C, N_T, N_X) or (B, N_T, N_X, C)
            as_prob: whether or not to normalize u(x,t) to sum to 1 (ie interpret u(x, t) as a probability distribution)
            seed: base random seed for reproducibility
            transform: optional callable (u_in, u_out) -> (u_in_aug, u_out_aug)
            initial_condition: optional function x->u0(x); if provided, it is used for the IC
            device: torch device
        """
        super().__init__()
        self.N = N
        self.B = B
        self.N_x = N_x
        self.L = X[1] - X[0]
        self.X = X
        self.T = T
        self.D_range = D_range
        self.channels_first = channels_first
        self.as_prob = as_prob
        self.include_D = include_D
        self.seed = seed
        self.transform = transform
        self.initial_condition = initial_condition

        if isinstance(device, str):
            self.device = torch.device(device)
        elif device is None:
            self.device = torch.device("cpu")
        else: 
            self.device = device

        # Precompute the spatial and temporal grids.
        # Note: when using an IC function, we perform a convolution over spatial grid,
        # so we only need the 1D grid and a time vector.
        self.x = torch.linspace(X[0], X[1], N_x, device=self.device)  # shape: [N_x]
        self.dx = (self.L/(N_x-1))
        self.t = torch.linspace(0, T, B, device=self.device)      # shape: [B]
        # For the closed-form branch we also need a meshgrid; we create it later on
        # in the else branch.
        self.x_grid, self.t_grid = torch.meshgrid(self.x, self.t, indexing='ij')  # shapes: [N_x, B]
        self.xt_grid = torch.stack([self.x_grid, self.t_grid], axis=-1).permute(1,0,-1) # shapes: [B, N_x, 2]
        

    def __len__(self):
        return self.N

    def __getitem__(self, idx):
        gen = torch.Generator(device=self.device)
        if self.seed is not None:
            gen.manual_seed(self.seed + idx)

        # Sample diffusion coefficient D for this trajectory
        D = torch.rand(1, generator=gen, device=self.device) * (self.D_range[1] - self.D_range[0]) + self.D_range[0]
        eps = 1e-8

        if self.initial_condition is not None:
            # Use the provided IC: u0 = initial_condition(x), shape [N_x]
            u0 = self.initial_condition(self.x)  # [N_x]
            u0 = u0 / u0.sum()
            dx = self.L / (self.N_x - 1)

            # The closed-form solution for diffusion with an arbitrary IC is
            #    u(x,t)=∫ K(x,x',t) u0(x') dx',
            # with the kernel
            #    K(x,x',t)= exp[-(x-x')^2/(4Dt)] / sqrt(4πDt).
            # We build a kernel for all time steps simultaneously.
            # Set up two copies of x for broadcasting:
            x_out = self.x.unsqueeze(1)  # shape: [N_x, 1]
            x_in  = self.x.unsqueeze(0)  # shape: [1, N_x]
            diff = x_out - x_in          # shape: [N_x, N_x]
            # Now set up a time vector for each time step.
            # t_exp: shape [1, 1, B]
            t_exp = self.t.unsqueeze(0).unsqueeze(0)
            # Now compute the kernel for all t:
            # kernel will have shape [N_x, N_x, B]
            kernel = torch.exp(- diff.unsqueeze(2)**2 / (4 * D * t_exp + eps)) / \
                     torch.sqrt(4 * torch.pi * D * t_exp + eps)
            # Now perform the convolution (sum over the integration variable x'):
            # u(x,t) = sum_{x'} kernel(x, x', t) * u0(x') * dx.
            u = torch.einsum('ijn,j->in', kernel, u0) * dx  # shape: [N_x, B]
            u = u.T.contiguous()  # reshape to [B, N_x]
            u[0] = u0
        else:
            # no initial_condition is provided: use random Gaussian parameters.
            x0 = torch.rand(1, generator=gen, device=self.device) * 0.5 + 0.25
            sigma = torch.rand(1, generator=gen, device=self.device) * 0.15 + 0.05
            # Here, we already have self.x_grid (shape: [N_x, B]) and self.t_grid (shape: [N_x, B])
            sigma_t = sigma**2 + 2 * D * self.t_grid  # shape: [N_x, B]
            u = 1. / torch.sqrt(2 * torch.pi * sigma_t) * torch.exp(
                - (self.x_grid - x0)**2 / (2 * sigma_t)
            )  # shape: [N_x, B]
            u = u.T.contiguous()  # shape: [B, N_x]

        u = u.unsqueeze(0) if self.channels_first else u.unsqueeze(-1)
        # Apply any augmentations to the solution, if provided.
        xt_grid = self.xt_grid
        if self.transform:
            xt_grid = self.transform(xt_grid)

        if self.as_prob:
            u = u / (u.sum(dim=1, keepdim=True) + 1e-8)  # Normalize by sum to 1
        #print(u.shape)
        # Finally, if include_D is True, append D as an extra channel to u_in.
        if self.include_D:
            # D is a scalar here; expand it to match [B-1, N_x, 1] (unchanged in time and space)
            D_feat = D.expand(xt_grid.shape[0], xt_grid.shape[1], 1)
            xt_grid = torch.cat([xt_grid, D_feat], dim=-1)  # shape becomes [B, N_x, 3]

        if self.channels_first:
            xt_grid = xt_grid.permute(2,0,1)

            
        return {"x":xt_grid.to(self.device), "y": u.to(self.device)}

# %% [markdown]
# ## Helper Classes

# %% [markdown]
# ### Augmentations

# %%
class AddGaussianNoise:
    def __init__(self, std=0.01):
        self.std = std

    def __call__(self, u_in, u_out):
        noise = torch.randn_like(u_in) * self.std
        return u_in + noise, u_out

# %% [markdown]
# ### Initial Conditions

# %%
def center_peak_ic(x, amplitude=1.0, width=0.1):
    """
    Generates an initial condition with a Gaussian peak centered in the middle of the domain.
    
    Parameters:
    - x (torch.Tensor): The spatial grid, a 1D tensor representing spatial points.
    - amplitude (float): The peak value at the center (default: 1.0).
    - width (float): The width of the peak. Controls how quickly the value decays away from the center (default: 0.1).
    
    Returns:
    - torch.Tensor: The initial condition profile with a peak at the center of the domain.
    """
    
    # Calculate the distance from the center (center is x[len(x) // 2])
    distance = torch.abs(x - x[len(x) // 2])
    
    # Define the Gaussian profile
    profile = torch.exp(-distance**2 / (2 * width**2))
    
    # Scale by the amplitude to set the peak value at the center
    return amplitude * profile

# %%
def delta_ic_gaussian(x_grid, center=0.5, sigma=0.05):
    """
    Approximates a Dirac delta centered at `center` using a narrow Gaussian.
    
    Args:
        x_grid (torch.Tensor): (N_x,) spatial grid
        center (float): location of the spike (default 0.5)
        sigma (float): width of the Gaussian (default 0.01)
    
    Returns:
        u0 (torch.Tensor): (N_x,) normalized initial condition
    """
    u0 = torch.exp(-0.5 * ((x_grid - center) / sigma) ** 2)
    u0 = u0 / (u0.sum() * (x_grid[1] - x_grid[0]))  # normalize to integrate to 1
    return u0

# %%
def no_batching_fn(data):
    return data[0]

# %% [markdown]
# ## Visualize Data

# %% [markdown]
# ### Instantiate Data

# %%
ds = BrownianMotionDataset(
    N=1000, include_D=False, seed=42,
    initial_condition=None, as_prob=True
)

# %% [markdown]
# ### Check single input shapes

# %%
data_dict = ds[1]
grid = data_dict["x"]; u_t = data_dict["y"]
grid.shape, u_t.shape
# Out:
# (torch.Size([100, 128, 2]), torch.Size([100, 128, 1]))

# %% [markdown]
# ### Visualize data

# %%
fig, axs = plt.subplots(3,3)
k=0
for i in range(3):
    for j in range(3):
        data_dict = ds[k]
        traj_t = data_dict["y"]
        #print(traj_t.sum(axis=1))
        im = axs[i,j].imshow(traj_t.squeeze().T, aspect="auto")
        k+=1
fig.colorbar(im)
fig.supxlabel("t")
fig.supylabel("x")
# Out:
# Text(0.02, 0.5, 'x')

# %%
fig, axs = plt.subplots(3,3)
k=0
for i in range(3):
    for j in range(3):
        data_dict = ds[k]
        traj_t = data_dict["y"]
        #print(traj_t.sum(axis=1).shape)
        axs[i,j].plot(traj_t[:, np.random.choice(np.arange(traj_t.shape[1])), 0].squeeze())
        k+=1

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Setup dataloader

# %%
ds = BrownianMotionDataset(
    N=10000, include_D=False, seed=42,
    initial_condition=None, as_prob=True, channels_first=True,
    device=torch.device("mps")
)
data_dict = ds[0]
u_t = data_dict["x"]; u_t_1 = data_dict["y"]
u_t.device
# Out:
# device(type='mps', index=0)

# %%
dl = torch.utils.data.DataLoader(ds, batch_size=32, drop_last=True)
data = next(iter(dl))
data["x"].shape
# Out:
# torch.Size([32, 2, 100, 128])

# %% [markdown]
# ### Setup logging

# %%
run = wandb.init(entity="aaprasad",
                 project="opLDS",
                 dir="./logs",
                 name="test_FNO2d_brownian_v1",
                 notes="initial attempt at training fno2d on brownian motion",
                 )
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: aaprasad (talmolab) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>./logs/wandb/run-20250418_110105-bbmbkc3y</code>
# Syncing run <strong><a href='https://wandb.ai/aaprasad/opLDS/runs/bbmbkc3y' target="_blank">test_FNO2d_brownian_v1</a></strong> to <a href='https://wandb.ai/aaprasad/opLDS' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aaprasad/opLDS' target="_blank">https://wandb.ai/aaprasad/opLDS</a>
#  View run at <a href='https://wandb.ai/aaprasad/opLDS/runs/bbmbkc3y' target="_blank">https://wandb.ai/aaprasad/opLDS/runs/bbmbkc3y</a>

# %% [markdown]
# ### Initialize Model, trainer and optimizer

# %%
model = FNO(n_modes=(16,16), in_channels=2, hidden_channels=16, out_channels=1)

# %%
trainer = Trainer(model=model, n_epochs=100, device=torch.device("mps"), wandb_log=True, verbose=True)

# %%
optim = torch.optim.Adam(model.parameters())
scheduler = torch.optim.lr_scheduler.ConstantLR(optim)

# %% [markdown]
# ### Train Model

# %%
trainer.train(dl, test_loaders={"test":dl}, eval_losses={"mse": LpLoss()}, optimizer=optim, scheduler=scheduler, training_loss=LpLoss(), save_best="test_mse", save_dir="./ckpt/fno2d")
# Out:
# Training on 10000 samples
# Testing on [10000] samples         on resolutions ['test'].
# Raw outputs of shape torch.Size([32, 1, 100, 128])
# [0] time=42.24, avg_loss=74.8474, train_err=2395.1182
# Eval: test_mse=27.9049
# [Rank 0]: saved training state to ./ckpt/fno2d
# [1] time=41.31, avg_loss=16.5419, train_err=529.3418
# Eval: test_mse=16.6284
# [Rank 0]: saved training state to ./ckpt/fno2d
# [2] time=41.59, avg_loss=14.1122, train_err=451.5907
# Eval: test_mse=12.5156
# [Rank 0]: saved training state to ./ckpt/fno2d
# [3] time=41.13, avg_loss=11.7122, train_err=374.7889
# Eval: test_mse=10.9384
# [Rank 0]: saved training state to ./ckpt/fno2d
# [4] time=41.75, avg_loss=10.9307, train_err=349.7818
# Eval: test_mse=10.9522
# [5] time=41.42, avg_loss=12.8756, train_err=412.0200
# Eval: test_mse=11.3207
# [6] time=41.33, avg_loss=11.5322, train_err=369.0316
# Eval: test_mse=12.1885
# [7] time=41.69, avg_loss=10.9053, train_err=348.9694
# Eval: test_mse=9.9427
# [Rank 0]: saved training state to ./ckpt/fno2d
# [8] time=41.62, avg_loss=10.5163, train_err=336.5216
# Eval: test_mse=11.2141
# [9] time=41.50, avg_loss=10.4842, train_err=335.4929
# Eval: test_mse=11.4856
# [10] time=41.09, avg_loss=12.6081, train_err=403.4600
# Eval: test_mse=12.4275
# [11] time=41.77, avg_loss=12.1063, train_err=387.4020
# Eval: test_mse=12.6814
# [12] time=41.00, avg_loss=11.3782, train_err=364.1030
# Eval: test_mse=11.8840
# [13] time=41.93, avg_loss=10.9709, train_err=351.0689
# Eval: test_mse=9.4520
# [Rank 0]: saved training state to ./ckpt/fno2d
# [14] time=41.83, avg_loss=9.5138, train_err=304.4410
# Eval: test_mse=9.5862
# [15] time=41.44, avg_loss=9.6512, train_err=308.8386
# Eval: test_mse=9.5593
# [16] time=41.51, avg_loss=9.8888, train_err=316.4421
# Eval: test_mse=9.4451
# [Rank 0]: saved training state to ./ckpt/fno2d
# [17] time=41.37, avg_loss=9.9339, train_err=317.8839
# Eval: test_mse=10.6325
# [18] time=41.90, avg_loss=11.4214, train_err=365.4859
# Eval: test_mse=11.6487
# [19] time=41.44, avg_loss=11.2654, train_err=360.4930
# Eval: test_mse=9.5859
# [20] time=41.62, avg_loss=9.4347, train_err=301.9119
# Eval: test_mse=9.4308
# [Rank 0]: saved training state to ./ckpt/fno2d
# [21] time=41.96, avg_loss=9.5913, train_err=306.9220
# Eval: test_mse=9.6352
# [22] time=41.68, avg_loss=9.7298, train_err=311.3529
# Eval: test_mse=9.3361
# [Rank 0]: saved training state to ./ckpt/fno2d
# [23] time=41.47, avg_loss=9.7917, train_err=313.3350
# Eval: test_mse=10.1792
# [24] time=41.94, avg_loss=9.7580, train_err=312.2546
# Eval: test_mse=9.2364
# [Rank 0]: saved training state to ./ckpt/fno2d
# [25] time=41.26, avg_loss=9.7243, train_err=311.1772
# Eval: test_mse=9.6073
# [26] time=41.21, avg_loss=9.7085, train_err=310.6711
# Eval: test_mse=9.4107
# [27] time=41.40, avg_loss=9.6265, train_err=308.0478
# Eval: test_mse=9.2060
# [Rank 0]: saved training state to ./ckpt/fno2d
# [28] time=42.11, avg_loss=10.2047, train_err=326.5507
# Eval: test_mse=12.8842
# [29] time=43.80, avg_loss=10.4967, train_err=335.8944
# Eval: test_mse=9.2074
# [30] time=43.27, avg_loss=9.1825, train_err=293.8387
# Eval: test_mse=9.1402
# [Rank 0]: saved training state to ./ckpt/fno2d
# [31] time=42.02, avg_loss=9.3424, train_err=298.9565
# Eval: test_mse=9.8985
# [32] time=41.59, avg_loss=9.4012, train_err=300.8373
# Eval: test_mse=9.4040
# [33] time=41.64, avg_loss=9.7728, train_err=312.7309
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 trainer.train(dl, test_loaders={"test":dl}, eval_losses={"mse": LpLoss()}, optimizer=optim, scheduler=scheduler, training_loss=LpLoss(), save_best="test_mse", save_dir="./ckpt/fno2d")
#
# File ~/opssm/src/neuraloperator/neuralop/training/trainer.py:219, in Trainer.train(self, train_loader, test_loaders, optimizer, scheduler, regularizer, training_loss, eval_losses, save_every, save_best, save_dir, resume_from_dir)
#     210 epoch_metrics = dict(
#     211     train_err=train_err,
#     212     avg_loss=avg_loss,
#     213     avg_lasso_loss=avg_lasso_loss,
#     214     epoch_train_time=epoch_train_time
#     215 )
#     217 if epoch % self.eval_interval == 0:
#     218     # evaluate and gather metrics across each loader in test_loaders
# --> 219     eval_metrics = self.evaluate_all(epoch=epoch,
#     220                                     eval_losses=eval_losses,
#     221                                     test_loaders=test_loaders)
#     223     epoch_metrics.update(**eval_metrics)
#     224     # save checkpoint if conditions are met
#
# File ~/opssm/src/neuraloperator/neuralop/training/trainer.py:312, in Trainer.evaluate_all(self, epoch, eval_losses, test_loaders)
#     310 all_metrics = {}
#     311 for loader_name, loader in test_loaders.items():
# --> 312     loader_metrics = self.evaluate(eval_losses, loader,
#     313                             log_prefix=loader_name)
#     314     all_metrics.update(**loader_metrics)
#     315 if self.verbose:
#
# File ~/opssm/src/neuraloperator/neuralop/training/trainer.py:365, in Trainer.evaluate(self, loss_dict, data_loader, log_prefix, epoch)
#     363 if idx == len(data_loader) - 1:
#     364     return_output = True
# --> 365 eval_step_losses, outs = self.eval_one_batch(sample, loss_dict, return_output=return_output)
#     367 for loss_name, val_loss in eval_step_losses.items():
#     368     errors[f"{log_prefix}_{loss_name}"] += val_loss
#
# File ~/opssm/src/neuraloperator/neuralop/training/trainer.py:491, in Trainer.eval_one_batch(self, sample, eval_losses, return_output)
#     483     sample = {
#     484         k: v.to(self.device)
#     485         for k, v in sample.items()
#     486         if torch.is_tensor(v)
#     487     }
#     489 self.n_samples += sample["y"].size(0)
# --> 491 out = self.model(**sample)
#     493 if self.data_processor is not None:
#     494     out, sample = self.data_processor.postprocess(out, sample)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/opssm/src/neuraloperator/neuralop/models/fno.py:382, in FNO.forward(self, x, output_shape, **kwargs)
#     379     x = self.domain_padding.pad(x)
#     381 for layer_idx in range(self.n_layers):
# --> 382     x = self.fno_blocks(x, layer_idx, output_shape=output_shape[layer_idx])
#     384 if self.domain_padding is not None:
#     385     x = self.domain_padding.unpad(x)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/opssm/src/neuraloperator/neuralop/layers/fno_block.py:291, in FNOBlocks.forward(self, x, index, output_shape)
#     289     return self.forward_with_preactivation(x, index, output_shape)
#     290 else:
# --> 291     return self.forward_with_postactivation(x, index, output_shape)
#
# File ~/opssm/src/neuraloperator/neuralop/layers/fno_block.py:307, in FNOBlocks.forward_with_postactivation(self, x, index, output_shape)
#     304     else:
#     305         x = torch.tanh(x)
# --> 307 x_fno = self.convs[index](x, output_shape=output_shape)
#     308 #self.convs(x, index, output_shape=output_shape)
#     310 if self.norm is not None:
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/opssm/src/neuraloperator/neuralop/layers/spectral_convolution.py:486, in SpectralConv.forward(self, x, output_shape)
#     483 else:
#     484     slices_x[-1] = slice(None)
# --> 486 out_fft[slices_x] = self._contract(x[slices_x], weight, separable=self.separable)
#     488 if self.resolution_scaling_factor is not None and output_shape is None:
#     489     mode_sizes = tuple([round(s * r) for (s, r) in zip(mode_sizes, self.resolution_scaling_factor)])
#
# File ~/opssm/src/neuraloperator/neuralop/layers/spectral_convolution.py:46, in _contract_dense(x, weight, separable)
#      44     return einsum_complexhalf(eq, x, weight)
#      45 else:
# ---> 46     return tl.einsum(eq, x, weight)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/tensorly/backend/__init__.py:202, in BackendManager.dispatch_backend_method.<locals>.wrapped_backend_method(*args, **kwargs)
#     198 def wrapped_backend_method(*args, **kwargs):
#     199     """A dynamically dispatched method
#     200
#     201     Returns the queried method from the currently set backend"""
# --> 202     return getattr(
#     203         cls._THREAD_LOCAL_DATA.__dict__.get("backend", cls._backend), name
#     204     )(*args, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/tensorly/plugins.py:77, in use_opt_einsum.<locals>.cached_einsum(equation, *args)
#      74     expression = oe.contract_expression(equation, *shapes, optimize=optimize)
#      75     OPT_EINSUM_PATH_CACHE[key] = expression
# ---> 77 return expression(*args)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/opt_einsum/contract.py:895, in ContractExpression.__call__(self, out, backend, evaluate_constants, *arrays)
#     892     if backends.has_backend(backend) and all(infer_backend(x) == "numpy" for x in arrays):
#     893         return self._contract_with_conversion(ops, out, backend, evaluate_constants=evaluate_constants)
# --> 895     return self._contract(ops, out=out, backend=backend, evaluate_constants=evaluate_constants)
#     897 except ValueError as err:
#     898     original_msg = str(err.args) if err.args else ""
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/opt_einsum/contract.py:816, in ContractExpression._contract(self, arrays, out, backend, evaluate_constants)
#     813 """The normal, core contraction."""
#     814 contraction_list = self._full_contraction_list if evaluate_constants else self.contraction_list
# --> 816 return _core_contract(
#     817     list(arrays),
#     818     contraction_list,
#     819     out=out,
#     820     backend=backend,
#     821     evaluate_constants=evaluate_constants,
#     822     **self.kwargs,
#     823 )
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/opt_einsum/contract.py:702, in _core_contract(operands_, contraction_list, backend, evaluate_constants, out, **kwargs)
#     700     if handle_out:
#     701         out_kwarg = out
# --> 702     new_view = _einsum(einsum_str, *tmp_operands, backend=backend, out=out_kwarg, **kwargs)
#     704 # Append new items and dereference what we can
#     705 operands.append(new_view)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/opt_einsum/sharing.py:164, in einsum_cache_wrap.<locals>.cached_einsum(*args, **kwargs)
#     161 @functools.wraps(einsum)
#     162 def cached_einsum(*args, **kwargs):
#     163     if not currently_sharing():
# --> 164         return einsum(*args, **kwargs)
#     166     # hash modulo commutativity by computing a canonical ordering and names
#     167     backend = kwargs.pop("backend", "numpy")
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/opt_einsum/contract.py:451, in _einsum(*operands, **kwargs)
#     448     einsum_str = parser.convert_to_valid_einsum_chars(einsum_str)
#     450 kwargs = _filter_einsum_defaults(kwargs)  # type: ignore
# --> 451 return fn(einsum_str, *operands, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/opt_einsum/backends/torch.py:48, in einsum(equation, *operands, **kwargs)
#      45 equation = convert_to_valid_einsum_chars(equation)
#      47 torch, _ = _get_torch_and_device()
# ---> 48 return torch.einsum(equation, operands)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/torch/functional.py:402, in einsum(*args)
#     399     _operands = operands[0]
#     400     # recurse incase operands contains value that has torch function
#     401     # in the original implementation this line is omitted
# --> 402     return einsum(equation, *_operands)
#     404 if len(operands) <= 2 or not opt_einsum.enabled:
#     405     # the path for contracting 0 or 1 time(s) is already optimized
#     406     # or the user has disabled using opt_einsum
#     407     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/torch/functional.py:407, in einsum(*args)
#     402     return einsum(equation, *_operands)
#     404 if len(operands) <= 2 or not opt_einsum.enabled:
#     405     # the path for contracting 0 or 1 time(s) is already optimized
#     406     # or the user has disabled using opt_einsum
# --> 407     return _VF.einsum(equation, operands)  # type: ignore[attr-defined]
#     409 path = None
#     410 if opt_einsum.is_available():
#
# KeyboardInterrupt:

# %%
run.finish()
# Out:
# Error in callback <bound method _WandbInit._resume_backend of <wandb.sdk.wandb_init._WandbInit object at 0x304b7b310>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 31ae4af10, raw_cell="run.finish()" store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/AadityaPrasad_1/opssm/run/notebooks/train_fno2d.ipynb#X55sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:552, in _WandbInit._resume_backend(self, *args, **kwargs)
#     550 if self.backend is not None and self.backend.interface is not None:
#     551     self._logger.info("resuming backend")  # type: ignore
# --> 552     self.backend.interface.publish_resume()
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:777, in InterfaceBase.publish_resume(self)
#     775 def publish_resume(self) -> None:
#     776     resume = pb.ResumeRequest()
# --> 777     self._publish_resume(resume)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:293, in InterfaceShared._publish_resume(self, resume)
#     291 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     292     rec = self._make_request(resume=resume)
# --> 293     self._publish(rec)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 run.finish()
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:387, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     384     run_id = self._attach_id
#     386 with wb_logging.log_to_run(run_id):
# --> 387     return func(self, *args, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:483, in _run_decorator._noop.<locals>.wrapper(self, *args, **kwargs)
#     480         wandb.termwarn(message, repeat=False)
#     481         return cls.Dummy()
# --> 483 return func(self, *args, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:425, in _run_decorator._attach.<locals>.wrapper(self, *args, **kwargs)
#     423         raise e
#     424     cls._is_attaching = ""
# --> 425 return func(self, *args, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2182, in Run.finish(self, exit_code, quiet)
#    2174 if quiet is not None:
#    2175     deprecate.deprecate(
#    2176         field_name=deprecate.Deprecated.run__finish_quiet,
#    2177         warning_message=(
#    (...)   2180         ),
#    2181     )
# -> 2182 return self._finish(exit_code)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:387, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     384     run_id = self._attach_id
#     386 with wb_logging.log_to_run(run_id):
# --> 387     return func(self, *args, **kwargs)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:2190, in Run._finish(self, exit_code)
#    2184 @_log_to_run
#    2185 def _finish(
#    2186     self,
#    2187     exit_code: int | None = None,
#    2188 ) -> None:
#    2189     logger.info(f"finishing run {self._get_path()}")
# -> 2190     with telemetry.context(run=self) as tel:
#    2191         tel.feature.finish = True
#    2193     # Run hooks that need to happen before the last messages to the
#    2194     # internal service, like Jupyter hooks.
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/telemetry.py:42, in _TelemetryObject.__exit__(self, exctype, excinst, exctb)
#      40 if not self._run:
#      41     return
# ---> 42 self._run._telemetry_callback(self._obj)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:783, in Run._telemetry_callback(self, telem_obj)
#     781 self._telemetry_obj.MergeFrom(telem_obj)
#     782 self._telemetry_obj_dirty = True
# --> 783 self._telemetry_flush()
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:796, in Run._telemetry_flush(self)
#     794 if serialized == self._telemetry_obj_flushed:
#     795     return
# --> 796 self._backend.interface._publish_telemetry(self._telemetry_obj)
#     797 self._telemetry_obj_flushed = serialized
#     798 self._telemetry_obj_dirty = False
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:60, in InterfaceShared._publish_telemetry(self, telem)
#      58 def _publish_telemetry(self, telem: tpb.TelemetryRecord) -> None:
#      59     rec = self._make_record(telemetry=telem)
# ---> 60     self._publish(rec)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x304b7b310>> (for post_run_cell), with arguments args (<ExecutionResult object at 31aee5950, execution_count=19 error_before_exec=None error_in_exec=[Errno 32] Broken pipe info=<ExecutionInfo object at 31ae4af10, raw_cell="run.finish()" store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/AadityaPrasad_1/opssm/run/notebooks/train_fno2d.ipynb#X55sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:547, in _WandbInit._pause_backend(self, *args, **kwargs)
#     545 if self.backend.interface is not None:
#     546     self._logger.info("pausing backend")  # type: ignore
# --> 547     self.backend.interface.publish_pause()
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:769, in InterfaceBase.publish_pause(self)
#     767 def publish_pause(self) -> None:
#     768     pause = pb.PauseRequest()
# --> 769     self._publish_pause(pause)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:289, in InterfaceShared._publish_pause(self, pause)
#     287 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     288     rec = self._make_request(pause=pause)
# --> 289     self._publish(rec)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %% [markdown]
# ## Investigate Model Results

# %% [markdown]
# ### Visualize results at the end of training

# %%
_ = model.eval()
data = ds[0]
with torch.no_grad():
    preds = model(data["x"].unsqueeze(0)).cpu().squeeze()
fig,axs = plt.subplots(1,2)
axs[0].imshow(preds)
axs[1].imshow(data["y"].squeeze().cpu().numpy())
# Out:
# Error in callback <bound method _WandbInit._resume_backend of <wandb.sdk.wandb_init._WandbInit object at 0x304b7b310>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 31d7cdfd0, raw_cell="_ = model.eval()
# data = ds[0]
# with torch.no_grad().." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/AadityaPrasad_1/opssm/run/notebooks/train_fno2d.ipynb#X51sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:552, in _WandbInit._resume_backend(self, *args, **kwargs)
#     550 if self.backend is not None and self.backend.interface is not None:
#     551     self._logger.info("resuming backend")  # type: ignore
# --> 552     self.backend.interface.publish_resume()
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:777, in InterfaceBase.publish_resume(self)
#     775 def publish_resume(self) -> None:
#     776     resume = pb.ResumeRequest()
# --> 777     self._publish_resume(resume)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:293, in InterfaceShared._publish_resume(self, resume)
#     291 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     292     rec = self._make_request(resume=resume)
# --> 293     self._publish(rec)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x304b7b310>> (for post_run_cell), with arguments args (<ExecutionResult object at 31d7cc810, execution_count=18 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 31d7cdfd0, raw_cell="_ = model.eval()
# data = ds[0]
# with torch.no_grad().." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/AadityaPrasad_1/opssm/run/notebooks/train_fno2d.ipynb#X51sZmlsZQ%3D%3D> result=<matplotlib.image.AxesImage object at 0x319c6e1d0>>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:547, in _WandbInit._pause_backend(self, *args, **kwargs)
#     545 if self.backend.interface is not None:
#     546     self._logger.info("pausing backend")  # type: ignore
# --> 547     self.backend.interface.publish_pause()
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:769, in InterfaceBase.publish_pause(self)
#     767 def publish_pause(self) -> None:
#     768     pause = pb.PauseRequest()
# --> 769     self._publish_pause(pause)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:289, in InterfaceShared._publish_pause(self, pause)
#     287 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     288     rec = self._make_request(pause=pause)
# --> 289     self._publish(rec)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %% [markdown]
# ### Visualize Best Model Predictions

# %%
fig,axs = plt.subplots(10,2, figsize=(10, 20))
model.load_state_dict(torch.load("./ckpt/fno2d/best_model_state_dict.pt", weights_only=False))
_ = model.eval()
test_inds = np.random.choice(np.arange(len(ds)),size=10, replace=False)
for i,j in enumerate(test_inds):
    
    data = ds[int(j)]
    with torch.no_grad():
        preds = model(data["x"].unsqueeze(0)).cpu().squeeze()

    axs[i, 0].imshow(preds)
    im = axs[i, 1].imshow(data["y"].squeeze().cpu().numpy())

    axs[i,0].set_ylabel(f"sample {i}")

axs[0,0].set_title(r"$\hat{u}(x,t)$")
axs[0,1].set_title(r"$u(x,t)$")
fig.supxlabel("x")
fig.supylabel("t")
# fig.colorbar(im)
fig.tight_layout()
# Out:
# Error in callback <bound method _WandbInit._resume_backend of <wandb.sdk.wandb_init._WandbInit object at 0x304b7b310>> (for pre_run_cell), with arguments args (<ExecutionInfo object at 31b6a3f50, raw_cell="fig,axs = plt.subplots(10,2, figsize=(10, 20))
# mod.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/AadityaPrasad_1/opssm/run/notebooks/train_fno2d.ipynb#X53sZmlsZQ%3D%3D>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:552, in _WandbInit._resume_backend(self, *args, **kwargs)
#     550 if self.backend is not None and self.backend.interface is not None:
#     551     self._logger.info("resuming backend")  # type: ignore
# --> 552     self.backend.interface.publish_resume()
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:777, in InterfaceBase.publish_resume(self)
#     775 def publish_resume(self) -> None:
#     776     resume = pb.ResumeRequest()
# --> 777     self._publish_resume(resume)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:293, in InterfaceShared._publish_resume(self, resume)
#     291 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     292     rec = self._make_request(resume=resume)
# --> 293     self._publish(rec)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x304b7b310>> (for post_run_cell), with arguments args (<ExecutionResult object at 31b6a2b10, execution_count=20 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 31b6a3f50, raw_cell="fig,axs = plt.subplots(10,2, figsize=(10, 20))
# mod.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/AadityaPrasad_1/opssm/run/notebooks/train_fno2d.ipynb#X53sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:547, in _WandbInit._pause_backend(self, *args, **kwargs)
#     545 if self.backend.interface is not None:
#     546     self._logger.info("pausing backend")  # type: ignore
# --> 547     self.backend.interface.publish_pause()
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:769, in InterfaceBase.publish_pause(self)
#     767 def publish_pause(self) -> None:
#     768     pause = pb.PauseRequest()
# --> 769     self._publish_pause(pause)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:289, in InterfaceShared._publish_pause(self, pause)
#     287 def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     288     rec = self._make_request(pause=pause)
# --> 289     self._publish(rec)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:39, in InterfaceSock._publish(self, record, local)
#      37 def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38     self._assign(record)
# ---> 39     self._sock_client.send_record_publish(record)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:174, in SockClient.send_record_publish(self, record)
#     172 server_req.request_id = record.control.mailbox_slot
#     173 server_req.record_publish.CopyFrom(record)
# --> 174 self.send_server_request(server_req)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:154, in SockClient.send_server_request(self, msg)
#     153 def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 154     self._send_message(msg)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:151, in SockClient._send_message(self, msg)
#     149 header = struct.pack("<BI", ord("W"), raw_size)
#     150 with self._lock:
# --> 151     self._sendall_with_error_handle(header + data)
#
# File ~/miniforge3/envs/oplds/lib/python3.11/site-packages/wandb/sdk/lib/sock_client.py:130, in SockClient._sendall_with_error_handle(self, data)
#     128 start_time = time.monotonic()
#     129 try:
# --> 130     sent = self._sock.send(data)
#     131     # sent equal to 0 indicates a closed socket
#     132     if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe
